# %% [markdown]
# # Automatic Cytoscape Session Generator for KEGG
#
# ### What's This?
# This script creates Cytoscape session from a list of KEGG Pathway IDs.
#
# ### Tested on:
# * KEGGScape 0.6.0
# * Cytoscape 3.2.0 SNAPSHOT
# * cy-rest build 9/9/2014

# %%
# Basic Setup

import requests
import json
import pandas as pd
import io

# Basic Setup
PORT_NUMBER = 1234
BASE = 'http://localhost:' + str(PORT_NUMBER) + '/v1/'

# KEGG API
KEGG_API_URL = 'http://rest.kegg.jp/'

# Header for posting data to the server as JSON
HEADERS = {'Content-Type': 'application/json'}

# %%
# Load Resource file
f = open('sample_data/kegg_pathway_list.txt')
pathway_list = f.read()
f.close()

lines = pathway_list.splitlines()
pathways = {}
for line in lines:
    parts = line.split(':')
    pathways[parts[1]] = parts[0]
    
sorted_pathways = sorted(pathways.items())
api_urls = []
for k, v in sorted_pathways:
    api_urls.append(KEGG_API_URL + 'get/' + v + '/kgml')

# Function to call Cytoscape REST API
def create_from_list(network_list):
    server_res = requests.post(BASE + 'networks?source=url&collection=KEGG Pathways', data=json.dumps(network_list), headers=HEADERS)
    print(server_res.content)
    return json.loads(server_res.content)

#requests.delete(BASE + 'networks')

print(json.dumps(create_from_list(api_urls), indent=4))
# Out:
# ('Allograft rejection', 'mmu05330')
# ('Antigen processing and presentation', 'mmu04612')
# ('Arachidonic acid metabolism', 'mmu00590')
# ('Axon guidance', 'mmu04360')
# ('Caffeine metabolism', 'mmu00232')
# ('Cell adhesion molecules (CAMs)', 'mmu04514')
# ('Drug metabolism', 'mmu00982')
# ('ECM-receptor interaction', 'mmu04512')
# ('Focal adhesion', 'mmu04510')
# ('Glutathione metabolism', 'mmu00480')
# ('Graft-versus-host disease', 'mmu05332')
# ('Leukocyte transendothelial migration', 'mmu04670')
# ('Linoleic acid metabolism', 'mmu00591')
# ('MAPK signaling pathway', 'mmu04010')
# ('Metabolism of xenobiotics by cytochrome P450', 'mmu00980')
# ('Natural killer cell mediated cytotoxicity', 'mmu04650')
# ('Pathways in cancer', 'mmu05200')
# ('Primary bile acid biosynthesis', 'mmu00120')
# ('Prostate cancer', 'mmu05215')
# ('Regulation of actin cytoskeleton', 'mmu04810')
# ('Retinol metabolism', 'mmu00830')
# ('Small cell lung cancer', 'mmu05222')
# ('Systemic lupus erythematosus', 'mmu05322')
# ('Tight junction', 'mmu04530')
# ('Viral myocarditis', 'mmu05416')
# ['http://rest.kegg.jp/get/mmu05330/kgml', 'http://rest.kegg.jp/get/mmu04612/kgml', 'http://rest.kegg.jp/get/mmu00590/kgml', 'http://rest.kegg.jp/get/mmu04360/kgml', 'http://rest.kegg.jp/get/mmu00232/kgml', 'http://rest.kegg.jp/get/mmu04514/kgml', 'http://rest.kegg.jp/get/mmu00982/kgml', 'http://rest.kegg.jp/get/mmu04512/kgml', 'http://rest.kegg.jp/get/mmu04510/kgml', 'http://rest.kegg.jp/get/mmu00480/kgml', 'http://rest.kegg.jp/get/mmu05332/kgml', 'http://rest.kegg.jp/get/mmu04670/kgml', 'http://rest.kegg.jp/get/mmu00591/kgml', 'http://rest.kegg.jp/get/mmu04010/kgml', 'http://rest.kegg.jp/get/mmu00980/kgml', 'http://rest.kegg.jp/get/mmu04650/kgml', 'http://rest.kegg.jp/get/mmu05200/kgml', 'http://rest.kegg.jp/get/mmu00120/kgml', 'http://rest.kegg.jp/get/mmu05215/kgml', 'http://rest.kegg.jp/get/mmu04810/kgml', 'http://rest.kegg.jp/get/mmu00830/kgml', 'http://rest.kegg.jp/get/mmu05222/kgml', 'http://rest.kegg.jp/get/mmu05322/kgml', 'http://rest.kegg.jp/get/mmu04530/kgml', 'http://rest.kegg.jp/get/mmu05416/kgml']
# [{"source":"http://rest.kegg.jp/get/mmu04810/kgml","networkSUID":[7050]},{"source":"http://rest.kegg.jp/get/mmu05416/kgml","networkSUID":[8152]},{"source":"http://rest.kegg.jp/get/mmu00980/kgml","networkSUID":[4558]},{"source":"http://rest.kegg.jp/get/mmu00982/kgml","networkSUID":[2022]},{"source":"http://rest.kegg.jp/get/mmu04670/kgml","networkSUID":[3496]},{"source":"http://rest.kegg.jp/get/mmu04010/kgml","networkSUID":[3936]},{"source":"http://rest.kegg.jp/get/mmu05332/kgml","networkSUID":[3408]},{"source":"http://rest.kegg.jp/get/mmu04514/kgml","networkSUID":[1266]},{"source":"http://rest.kegg.jp/get/mmu00830/kgml","networkSUID":[7368]},{"source":"http://rest.kegg.jp/get/mmu00480/kgml","networkSUID":[3028]},{"source":"http://rest.kegg.jp/get/mmu04512/kgml","networkSUID":[2408]},{"source":"http://rest.kegg.jp/get/mmu05222/kgml","networkSUID":[7620]},{"source":"http://rest.kegg.jp/get/mmu04612/kgml","networkSUID":[162]},{"source":"http://rest.kegg.jp/get/mmu00120/kgml","networkSUID":[6436]},{"source":"http://rest.kegg.jp/get/mmu00591/kgml","networkSUID":[3770]},{"source":"http://rest.kegg.jp/get/mmu05215/kgml","networkSUID":[6854]},{"source":"http://rest.kegg.jp/get/mmu05330/kgml","networkSUID":[52]},{"source":"http://rest.kegg.jp/get/mmu00232/kgml","networkSUID":[1142]},{"source":"http://rest.kegg.jp/get/mmu05200/kgml","networkSUID":[5598]},{"source":"http://rest.kegg.jp/get/mmu04360/kgml","networkSUID":[824]},{"source":"http://rest.kegg.jp/get/mmu00590/kgml","networkSUID":[310]},{"source":"http://rest.kegg.jp/get/mmu04530/kgml","networkSUID":[7902]},{"source":"http://rest.kegg.jp/get/mmu04650/kgml","networkSUID":[5194]},{"source":"http://rest.kegg.jp/get/mmu04510/kgml","networkSUID":[2686]},{"source":"http://rest.kegg.jp/get/mmu05322/kgml","networkSUID":[7762]}]
# [
#     {
#         "source": "http://rest.kegg.jp/get/mmu04810/kgml",
#         "networkSUID": [
#             7050
#         ]
#     },
#     {
#         "source": "http://rest.kegg.jp/get/mmu05416/kgml",
#         "networkSUID": [
#             8152
#         ]
#     },
#     {
#         "source": "http://rest.kegg.jp/get/mmu00980/kgml",
#         "networkSUID": [
#             4558
#         ]
#     },
#     {
#         "source": "http://rest.kegg.jp/get/mmu00982/kgml",
#         "networkSUID": [
#             2022
#         ]
#     },
#     {
#         "source": "http://rest.kegg.jp/get/mmu04670/kgml",
#         "networkSUID": [
#             3496
#         ]
#     },
#     {
#         "source": "http://rest.kegg.jp/get/mmu04010/kgml",
#         "networkSUID": [
#             3936
#         ]
#     },
#     {
#         "source": "http://rest.kegg.jp/get/mmu05332/kgml",
#         "networkSUID": [
#             3408
#         ]
#     },
#     {
#         "source": "http://rest.kegg.jp/get/mmu04514/kgml",
#         "networkSUID": [
#             1266
#         ]
#     },
#     {
#         "source": "http://rest.kegg.jp/get/mmu00830/kgml",
#         "networkSUID": [
#             7368
#         ]
#     },
#     {
#         "source": "http://rest.kegg.jp/get/mmu00480/kgml",
#         "networkSUID": [
#             3028
#         ]
#     },
#     {
#         "source": "http://rest.kegg.jp/get/mmu04512/kgml",
#         "networkSUID": [
#             2408
#         ]
#     },
#     {
#         "source": "http://rest.kegg.jp/get/mmu05222/kgml",
#         "networkSUID": [
#             7620
#         ]
#     },
#     {
#         "source": "http://rest.kegg.jp/get/mmu04612/kgml",
#         "networkSUID": [
#             162
#         ]
#     },
#     {
#         "source": "http://rest.kegg.jp/get/mmu00120/kgml",
#         "networkSUID": [
#             6436
#         ]
#     },
#     {
#         "source": "http://rest.kegg.jp/get/mmu00591/kgml",
#         "networkSUID": [
#             3770
#         ]
#     },
#     {
#         "source": "http://rest.kegg.jp/get/mmu05215/kgml",
#         "networkSUID": [
#             6854
#         ]
#     },
#     {
#         "source": "http://rest.kegg.jp/get/mmu05330/kgml",
#         "networkSUID": [
#             52
#         ]
#     },
#     {
#         "source": "http://rest.kegg.jp/get/mmu00232/kgml",
#         "networkSUID": [
#             1142
#         ]
#     },
#     {
#         "source": "http://rest.kegg.jp/get/mmu05200/kgml",
#         "networkSUID": [
#             5598
#         ]
#     },
#     {
#         "source": "http://rest.kegg.jp/get/mmu04360/kgml",
#         "networkSUID": [
#             824
#         ]
#     },
#     {
#         "source": "http://rest.kegg.jp/get/mmu00590/kgml",
#         "networkSUID": [
#             310
#         ]
#     },
#     {
#         "source": "http://rest.kegg.jp/get/mmu04530/kgml",
#         "networkSUID": [
#             7902
#         ]
#     },
#     {
#         "source": "http://rest.kegg.jp/get/mmu04650/kgml",
#         "networkSUID": [
#             5194
#         ]
#     },
#     {
#         "source": "http://rest.kegg.jp/get/mmu04510/kgml",
#         "networkSUID": [
#             2686
#         ]
#     },
#     {
#         "source": "http://rest.kegg.jp/get/mmu05322/kgml",
#         "networkSUID": [
#             7762
#         ]
#     }
# ]
