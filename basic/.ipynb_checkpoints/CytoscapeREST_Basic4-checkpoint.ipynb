# %% [markdown]
# ## Work with external web services
#
# ### KEGG API

# %%
import requests
import json
import pandas as pd
import io

# Basic Setup
PORT_NUMBER = 1234
BASE = 'http://localhost:' + str(PORT_NUMBER) + '/v1/'

# KEGG API
KEGG_API_URL = 'http://rest.kegg.jp/'

# Header for posting data to the server as JSON
HEADERS = {'Content-Type': 'application/json'}

requests.get(BASE)
# Out:
# <Response [200]>

# %%
# Find information about diabetes from KEGG disease database.
query = 'brain'
# query = 'diabetes'


res = requests.get(KEGG_API_URL + '/find/disease/' + query)
pathway_list = res.content.decode('utf8')

disease_df = pd.read_csv(io.StringIO(pathway_list), delimiter='\t',  header=None, names=['id', 'name'])
disease_df.head()
# Out:
#           id                                               name
# 0  ds:H00078  Frontotemporal lobar degeneration (FTLD), incl...
# 1  ds:H00120  Dystroglycanopathy; Walker-Warburg syndrome (W...
# 2  ds:H00590  Congenital muscular dystrophies (CMD/MDC), inc...
# 3  ds:H00727  Bosley-Salih-Alorainy syndrome and Athabascan ...
# 4  ds:H00833  Neurodegeneration with brain iron accumulation...
#
# [5 rows x 2 columns]

# %%
disease_ids = disease_df['id']
disease_urls = disease_ids.apply(lambda x: KEGG_API_URL + 'get/' + x)

def disease_parser(entry):
    lines = entry.split('\n')
    data = {}
    
    last_key = None
    for line in lines:
        if '///' in line:
            return data
        
        parts = line.split(' ')
        if parts[0] is not None and len(parts[0]) != 0:
            last_key = parts[0]
            data[parts[0]] = line.replace(parts[0], '').strip()
        else:
            last_val = data[last_key]
            data[last_key] = last_val + '|' + line.strip()
    return data
    
        

result = []
for url in disease_urls:
        res = requests.get(url)
        rows = disease_parser(res.content)
        result.append(rows)

# %%
disease_df = pd.DataFrame(result)
pathways = disease_df['PATHWAY'].dropna().unique()

p_urls = []
for pathway in pathways:
    entries = pathway.split('|')
    for en in entries:
        if 'hsa05200' not in en:
            p_urls.append(KEGG_API_URL + 'get/' + en.split(' ')[0].split('(')[0] + '/kgml')
        
        
def create_from_list(network_list):
    server_res = requests.post(BASE + 'networks?source=url', data=json.dumps(network_list), headers=HEADERS)
    print(server_res.content)
    return json.loads(server_res.content)

requests.delete(BASE + 'networks')

print(set(p_urls))
print(json.dumps(create_from_list(list(set(p_urls))), indent=4))
# Out:
# set(['http://rest.kegg.jp/get/hsa00590/kgml', 'http://rest.kegg.jp/get/hsa04510/kgml', 'http://rest.kegg.jp/get/hsa04310/kgml', 'http://rest.kegg.jp/get/hsa00564/kgml', 'http://rest.kegg.jp/get/hsa00970/kgml', 'http://rest.kegg.jp/get/hsa04666/kgml', 'http://rest.kegg.jp/get/hsa00591/kgml', 'http://rest.kegg.jp/get/hsa00770/kgml', 'http://rest.kegg.jp/
#         ]
#     },
#     {
#         "source": "http://rest.kegg.jp/get/hsa04666/kgml",
#         "networkSUID": [
#             28744
#         ]
#     },
#     {
#         "source": "http://rest.kegg.jp/get/hsa04664/kgml",
#         "networkSUID": [
#             31972
#         ]
#     },
#     {
#         "source": "http://rest.kegg.jp/get/hsa04510/kgml",
#         "networkSUID": [
#             26850
#         ]
#     },
#     {
#         "source": "http://rest.kegg.jp/get/hsa04010/kgml",
#         "networkSUID": [
#             31042
#         ]
#     },
#     {
#         "source": "http://rest.kegg.jp/get/hsa04810/kgml",
#         "networkSUID": [
#             32176
#         ]
#     },
#     {
#         "source": "http://rest.kegg.jp/get/hsa04920/kgml",
#         "networkSUID": [
#             34470
#         ]
#     },
#     {
#         "source": "http://rest.kegg.jp/get/hsa04978/kgml",
#         "networkSUID": [
#             30442
#         ]
#     },
#     {
#         "source": "http://rest.kegg.jp/get/hsa00970/kgml",
#         "networkSUID": [
#             28320
#         ]
#     },
#     {
#         "source": "http://rest.kegg.jp/get/hsa04330/kgml",
#         "networkSUID": [
#             30338
#         ]
#     },
#     {
#         "source": "http://rest.kegg.jp/get/hsa00514/kgml",
#         "networkSUID": [
#             32786
#         ]
#     },
#     {
#         "source": "http://rest.kegg.jp/get/hsa04976/kgml",
#         "networkSUID": [
#             30680
#         ]
#     },
#     {
#         "source": "http://rest.kegg.jp/get/hsa00590/kgml",
#         "networkSUID": [
#             25916
#         ]
#     },
#     {
#         "source": "http://rest.kegg.jp/get/hsa04144/kgml",
#         "networkSUID": [
#             33550
#         ]
#     },
#     {
#         "source": "http://rest.kegg.jp/get/hsa04722/kgml",
#         "networkSUID": [
#             33120
#         ]
#     },
#     {
#         "source": "http://rest.kegg.jp/get/hsa00770/kgml",
#         "networkSUID": [
#             29276
#         ]
#     },
#     {
#         "source": "http://rest.kegg.jp/get/hsa00565/kgml",
#         "networkSUID": [
#             29526
#         ]
#     },
#     {
#         "source": "http://rest.kegg.jp/get/hsa04530/kgml",
#         "networkSUID": [
#             29742
#         ]
#     },
#     {
#         "source": "http://rest.kegg.jp/get/hsa04730/kgml",
#         "networkSUID": [
#             32910
#         ]
#     },
#     {
#         "source": "http://rest.kegg.jp/get/hsa04726/kgml",
#         "networkSUID": [
#             32510
#         ]
#     },
#     {
#         "source": "http://rest.kegg.jp/get/hsa00591/kgml",
#         "networkSUID": [
#             29012
#         ]
#     },
#     {
#         "source": "http://rest.kegg.jp/get/hsa00860/kgml",
#         "networkSUID": [
#             33854
#         ]
#     },
#     {
#         "source": "http://rest.kegg.jp/get/hsa04310/kgml",
#         "networkSUID": [
#             27208
#         ]
#     },
#     {
#         "source": "http://rest.kegg.jp/get/hsa00564/kgml",
#         "networkSUID": [
#             27548
#         ]
#     },
#     {
#         "source": "http://rest.kegg.jp/get/hsa04141/kgml",
#         "networkSUID": [
#             30008
#         ]
#     }
# ]

# %%
res = requests.get(KEGG_API_URL + '/find/pathway/' + query)
pathway_list = res.content.decode('utf8')

df = pd.read_csv(io.StringIO(pathway_list), delimiter='\t',  header=None, names=['id', 'name'])
df.head()
# Out:
#               id                                  name
# 0  path:map04930             Type II diabetes mellitus
# 1  path:map04940              Type I diabetes mellitus
# 2  path:map04950  Maturity onset diabetes of the young

# %%
ids = df['id']
pathway_urls = ids.apply(lambda x: KEGG_API_URL + 'get/hsa' + x.split(':map')[1] + '/kgml')

url_list = pathway_urls.tolist()




# Remove all networks
requests.delete(BASE + 'networks')

print(json.dumps(create_from_list(url_list), indent=4))
# Out:
# [{"source":"http://rest.kegg.jp/get/hsa04940/kgml","networkSUID":[1114]},{"source":"http://rest.kegg.jp/get/hsa04930/kgml","networkSUID":[938]},{"source":"http://rest.kegg.jp/get/hsa04950/kgml","networkSUID":[1200]}]
# [
#     {
#         "source": "http://rest.kegg.jp/get/hsa04940/kgml",
#         "networkSUID": [
#             1114
#         ]
#     },
#     {
#         "source": "http://rest.kegg.jp/get/hsa04930/kgml",
#         "networkSUID": [
#             938
#         ]
#     },
#     {
#         "source": "http://rest.kegg.jp/get/hsa04950/kgml",
#         "networkSUID": [
#             1200
#         ]
#     }
# ]
