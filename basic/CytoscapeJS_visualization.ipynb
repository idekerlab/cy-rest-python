# %% [markdown]
# # Using Cytoscape.js in Jupyter Notebook
#
# by [Keiichiro Ono](http://keiono.github.io/)
#
# ----
#
# ![](http://cytoscape.org/images/logo/cy3logoOrange.svg)
#
#
# ![](http://upload.wikimedia.org/wikipedia/commons/thumb/6/6a/JavaScript-logo.png/240px-JavaScript-logo.png)
#
#
# ## Introduction
# If you use Jupyetr Notebook with cyREST, you can script your workflow.  And in some cases, you may want to embed the result in the notebook.  There are two ways to do it:
#
# * Embed static PNG image from Cytoscape
# * Convert the result into Cytoscape.js JSON objects, and use it with Cytoscape.js widget
#
# Second option is more appropreate for relatively large networks because users can zoom-in/out to see the detail.  In this section, you will learn how to use interactive network visualization widget in [py2cytoscape](https://github.com/idekerlab/py2cytoscape).

# %%
# Package to render networks in Cytoscape.js
from py2cytoscape import cytoscapejs as cyjs

# And standard JSON utility
import json

# %% [markdown]
# ## Loading Sample Network
# In this example, we use Cytoscape.js JSON files generated by Cytoscape.  Input data for this widget should be Cytoscape.js JSON format. You can create those in Cytoscape 3.2.1 OR you can build them programmatically with Python.

# %%
# Load network JSON file into this notebook session
yeast_network = json.load(open('sample_data/yeast.json')) # Simple yeast PPI network
kegg_pathway = json.load(open('sample_data/kegg_cancer.cyjs')) # KEGG Pathway

# %% [markdown]
# ## Loading Visual Styles (Optional)
# Although this widget includes some preset styles, we recommend to use your custom Visual Style.  If you just use Cytoscape.js widget, it is a bit hard to create complex styles manually, but you can interactively create those with Cytoscape 3.

# %%
# And Visual Style file in Cytoscape.js format.
vs_collection = json.load(open('sample_data/kegg_style.json'))

# Create map from Title to Style
def add_to_map(key, value, target):
    target[key] = value

styles = {}
map( lambda(x): add_to_map(x["title"], x["style"], styles), vs_collection)

# Display available style names
print(json.dumps(styles.keys(), indent=4))
# Out:
# [
#     "Directed",
#     "default",
#     "Nested Network Style",
#     "default black",
#     "Solid",
#     "BioPAX_SIF",
#     "KEGG Style",
#     "Sample1",
#     "BioPAX",
#     "Ripple",
#     "Big Labels",
#     "Universe",
#     "Minimal"
# ]

# %% [markdown]
# ## Render the result
# There are several options for visualization:
#
# * __style__ - Name of the preset visual style OR Style as JSON object.  Default is ___default___
# * __layout_algorithm__ - name of Cytoscape.js layout algorithm.  Default is ___preset___
# * __background__ - Background color.  Also accepts CSS!
#
# Here is the simplest example: just pass Cytoscape.js object

# %%
cyjs.render(yeast_network)
# Out:
# <!DOCTYPE html>
# <html>
#
# <head>
#     <meta charset=utf-8 />
#     <style type="text/css">
#       body {
#           font: 14px helvetica neue, helvetica, arial, sans-serif;
#       }
#
#       #cy02c10c31-3754-4c2f-82cc-6a0c0f4c4fa7 {
#         height: 700px;
#         width: 1098px;
#         position: absolute;
#         left: 4px;
#         top: 5px;
#         background: #FFFFFF;
#       }
#     </style>
#
#     <script>
#     (function() {
#       function render() {
#         $('#cy02c10c31-3754-4c2f-82cc-6a0c0f4c4fa7').cytoscape({
#             elements: {
#                 nodes: [{"position": {"y": 1625.5243491763981, "x": 1614.6005189933987}, "selected": false, "data": {"selected": false, "shared_name": "YIL162W", "id": "465", "name": "YIL162W", "SUID": 465}}, {"position": {"y": 1766.2711348086418, "x": 455.4464523478797}, "selected": false, "data": {"selected": false, "shared_name": "YOR355W", "id": "469", "name": "YOR355W", "SUID": 469}}, {"position": {"y": 2465.3122070399913, "x": 916.5960361506276}, "selected": false, "data": {"selected": false, "shared_name": "YFL038C", "id": "467", "name": "YFL038C", "SUID": 467}}, {"position": {"y": 596.4722875078844, "x": 682.288129044437}, "selected": false, "data": {"selected": false, "shared_name": "YML123C", "id": "477", "name": "YML123C", "SUID": 477}}, {"position": {"y": 2328.9479376143063, "x": 2526.1950023153504}, "selected": false, "data": {"
# %%
# With CSS-style Background - with gradient
cyjs.render(yeast_network, style="default2", background="radial-gradient(#FFFFFF 15%, #EEEEEE 105%)", layout_algorithm="breadthfirst")
# Out:
# <!DOCTYPE html>
# <html>
#
# <head>
#     <meta charset=utf-8 />
#     <style type="text/css">
#       body {
#           font: 14px helvetica neue, helvetica, arial, sans-serif;
#       }
#
#       #cy224885cf-afa5-445e-a3e9-2926c35e4888 {
#         height: 700px;
#         width: 1098px;
#         position: absolute;
#         left: 4px;
#         top: 5px;
#         background: radial-gradient(#FFFFFF 15%, #EEEEEE 105%);
#       }
#     </style>
#
#     <script>
#     (function() {
#       function render() {
#         $('#cy224885cf-afa5-445e-a3e9-2926c35e4888').cytoscape({
#             elements: {
#                 nodes: [{"position": {"y": 1625.5243491763981, "x": 1614.6005189933987}, "selected": false, "data": {"selected": false, "shared_name": "YIL162W", "id": "465", "name": "YIL162W", "SUID": 465}}, {"position": {"y": 1766.2711348086418, "x": 455.4464523478797}, "selected": false, "data": {"selected": false, "shared_name": "YOR355W", "id": "469", "name": "YOR355W", "SUID": 469}}, {"position": {"y": 2465.3122070399913, "x": 916.5960361506276}, "selected": false, "data": {"selected": false, "shared_name": "YFL038C", "id": "467", "name": "YFL038C", "SUID": 467}}, {"position": {"y": 596.4722875078844, "x": 682.288129044437}, "selected": false, "data": {"selected": false, "shared_name": "YML123C", "id": "477", "name": "YML123C", "SUID": 477}}, {"position": {"y": 2328.9479376143063, "x": 2526.1950023153504}, "selected": false, "data": {"selected": false, "shared_name": "YHR071W", "id": "480", "name": "YHR071W", "SUID": 480}}, {"position": {"y": 2266.5941085418267, "x": 2562.1950023153504}, "selected": false, "data": {"selected": false, "shared_name": "YPL031C", "id": "479", "name": "YPL031C", "SUID": 479}}, {"position": {"y": 1344.0127059386227, "x": 1568.850424010942}, "selected": false, "data": {"selected": false, "shared_name": "YDR009W", "id": "485", "name": "YDR009W", "SUID": 485}}, {"position": {"y": 1388.8813521332956, "x": 1585.8668569767663}, "selected": false, "data": {"selected": false, "shared_name": "YML051W", "id": "483", "name": "YML051W", "SUID": 483}}, {"position": {"y": 849.7788737775638, "x": 501.7975774494249}, "selected": false, "data": {"selected": false, "shared_name": "YML024W", "id": "490", "name": "YML024W", "SUID": 490}}, {"position": {"y": 888.8805962990978, "x": 450.91806644367614}, "selected": false, "data": {"selected": false, "shared_name": "YIL113W", "id": "488", "name": "YIL113W", "SUID": 488}}, {"position": {"y": 833.403642819241, "x": 405.0235391817705}, "selected": false, "data": {"selected": false, "shared_name": "YLL019C", "id": "487", "name": "YLL019C", "SUID": 487}}, {"position": {"y": 1116.0076544037533, "x": 643.7975664028373}, "selected": false, "data": {"selected": false, "shared_name": "YER111C", "id": "494", "name": "YER111C", "SUID": 494}}, {"position": {"y": 2461.004701152122, "x": 884.7967507246399}, "selected": false, "data": {"selected": false, "shared_name": "YGL161C", "id": "435", "name": "YGL161C", "SUID": 435}}, {"position": {"y": 2455.5584977566673, "x": 853.1725822904691}, "selected": false, "data": {"selected": false, "shared_name": "YDR100W", "id": "436", "name": "YDR100W", "SUID": 436}}, {"position": {"y": 2448.9806167522715, "x": 821.7642929058269}, "selected": false, "data": {"selected": false, "shared_name": "YMR183C", "id": "438", "name": "YMR183C", "SUID": 438}}, {"position": {"y": 2134.730082084332, "x": 809.3560750709172}, "selected": false, "data": {"selected": false, "shared_name": "YGR009C", "id": "439", "name": "YGR009C", "SUID": 439}}, {"position": {"y": 1039.231715685646, "x": 765.2090001010245}, "selected": false, "data": {"selected": false, "shared_name": "YAL040C", "id": "446", "name": "YAL040C", "SUID": 446}}, {"position": {"y": 664.5379273155334, "x": 705.7629810690057}, "selected": false, "data": {"selected": false, "shared_name": "YFR034C", "id": "448", "name": "YFR034C", "SUID": 448}}, {"position": {"y": 1808.551975126232, "x": 2608.2967241965234}, "selected": false, "data": {"selected": false, "shared_name": "YER133W", "id": "453", "name": "YER133W", "SUID": 453}}, {"position": {"y": 1850.6692303684067, "x": 2617.9760251920034}, "selected": false, "data": {"selected": false, "shared_name": "YOR178C", "id": "455", "name": "YOR178C", "SUID": 455}}, {"position": {"y": 1794.2132031759359, "x": 2687.122576275842}, "selected": false, "data": {"selected": false, "shared_name": "YOR315W", "id": "457", "name": "YOR315W", "SUID": 457}}, {"position": {"y": 1771.8433782890877, "x": 2664.7527513889945}, "selected": false, "data": {"selected": false, "sha ...

# %%
# And you can reproduce more complex styles created with Cytoscape 3!
cyjs.render(kegg_pathway, style=styles["KEGG Style"])
# Out:
# <!DOCTYPE html>
# <html>
#
# <head>
#     <meta charset=utf-8 />
#     <style type="text/css">
#       body {
#           font: 14px helvetica neue, helvetica, arial, sans-serif;
#       }
#
#       #cyc267268e-9408-4d5a-bf1c-28f1b48aa67d {
#         height: 700px;
#         width: 1098px;
#         position: absolute;
#         left: 4px;
#         top: 5px;
#         background: #FFFFFF;
#       }
#     </style>
#
#     <script>
#     (function() {
#       function render() {
#         $('#cyc267268e-9408-4d5a-bf1c-28f1b48aa67d').cytoscape({
#             elements: {
#                 nodes: [{"position": {"y": 1104.0, "x": 1159.0}, "selected": false, "data": {"KEGG_NODE_SHAPE": "rectangle", "KEGG_NODE_HEIGHT": "36", "KEGG_NODE_FILL_COLOR": "#FFFFFF", "name": "container", "SUID": 1022, "selected": false, "KEGG_NODE_TYPE": "group", "KEGG_NODE_WIDTH": "48", "KEGG_NODE_Y": "1104", "KEGG_NODE_X": "1159", "shared_name": "container", "id": "1022"}}, {"position": {"y": 365.0, "x": 1682.0}, "selected": false, "data": {"KEGG_NODE_SHAPE": "rectangle", "KEGG_NODE_HEIGHT": "36", "KEGG_NODE_FILL_COLOR": "#FFFFFF", "name": "container", "SUID": 1021, "selected": false, "KEGG_NODE_TYPE": "group", "KEGG_NODE_WIDTH": "48", "KEGG_NODE_Y": "365", "KEGG_NODE_X": "1682", "shared_name": "container", "id": "1021"}}, {"position": {"y": 141.0, "x": 1127.0}, "selected": false, "data": {"KEGG_NODE_SHAPE": "rectangle", "KEGG_NODE_HEIGHT": "53", "KEGG_NODE_FILL_COLOR": "#FFFFFF", "name": "container", "SUID": 1020, "selected": false, "KEGG_NODE_TYPE": "group", "KEGG_NODE_WIDTH": "94", "KEGG_NODE_Y": "141", "KEGG_NODE_X": "1127", "shared_name": "container", "id": "1020"}}, {"position": {"y": 220.0, "x": 279.0}, "selected": false, "data": {"KEGG_NODE_SHAPE": "rectangle", "KEGG_NODE_HEIGHT": "37", "KEGG_NODE_FILL_COLOR": "#FFFFFF", "name": "container", "SUID": 1019, "selected": false, "KEGG_NODE_TYPE": "group", "KEGG_NODE_WIDTH": "48", "KEGG_NODE_Y": "220", "KEGG_NODE_X": "279", "shared_name": "container", "id": "1019"}}, {"position": {"y": 182.0, "x": 835.0}, "selected": false, "data": {"KEGG_NODE_SHAPE": "rectangle", "KEGG_NODE_HEIGHT": "19", "KEGG_NODE_FILL_COLOR": "#FFFFFF", "name": "container", "SUID": 1018, "selected": false, "KEGG_NODE_TYPE": "group", "KEGG_NODE_WIDTH": "94", "KEGG_NODE_Y": "182", "KEGG_NODE_X": "835", "shared_name": "container", "id": "1018"}}, {"position": {"y": 752.0, "x": 1339.0}, "selected": false, "data": {"KEGG_NODE_SHAPE": "rectangle", "KEGG_NODE_HEIGHT": "36", "KEGG_NODE_FILL_COLOR": "#FFFFFF", "name": "container", "SUID": 1017, "selected": false, "KEGG_NODE_TYPE": "group", "KEGG_NODE_WIDTH": "48", "KEGG_NODE_Y": "752", "KEGG_NODE_X": "1339", "shared_name": "container", "id": "1017"}}, {"position": {"y": 694.0, "x": 1361.0}, "selected": false, "data": {"KEGG_NODE_SHAPE": "rectangle", "KEGG_NODE_HEIGHT": "36", "KEGG_NODE_FILL_COLOR": "#FFFFFF", "name": "container", "SUID": 1016, "selected": false, "KEGG_NODE_TYPE": "group", "KEGG_NODE_WIDTH": "48", "KEGG_NODE_Y": "694", "KEGG_NODE_X": "1361", "shared_name": "container", "id": "1016"}}, {"position": {"y": 714.0, "x": 1660.0}, "selected": false, "data": {"KEGG_NODE_SHAPE": "rectangle", "KEGG_NODE_HEIGHT": "36", "KEGG_NODE_FILL_COLOR": "#FFFFFF", "name": "container", "SUID": 1015, "selected": false, "KEGG_NODE_TYPE": "group", "KEGG_NODE_WIDTH": "48", "KEGG_NODE_Y": "714", "KEGG_NODE_X": "1660", "shared_name": "container", "id": "1015"}}, {"position": {"y": 84.0, "x": 1614.0}, "selected": false, "data": {"KEGG_NODE_SHAPE": "rectangle", "KEGG_NODE_HEIGHT": "36", "KEGG_NODE_FILL_COLOR": "#FFFFFF", "name": "container", "SUID": 1014, "selected": false, "KEGG_NODE_TYPE": "group", "KEGG_NODE_WIDTH": "48", "KEGG_NODE_Y": "84", "KEGG_NODE_X": "1614", "shared_name": "container", "id": "1014"}}, {"position": {"y": 686.0, "x": 311.0}, "selected": false, "data": {"KEGG_NODE_SHAPE": "rectangle", "KEGG_NODE_HEIGHT": "53", "KEGG_NODE_FILL_COLOR": "#FFFFFF", "name": "container", "SUID": 1013, "selected": false, "KEGG_NODE_TYPE": "group", "KEGG_NODE_WIDTH": "48", "KEGG_NODE_Y": "686", "KEGG_NODE_X": "311", "shared_name": "container", "id": "1013"}}, {"position": {"y": 545.0, "x": 133.0}, "selected": false, "data": {"KEGG_NODE_SHAPE": "rectangle", "KEGG_NODE_HEIGHT": "36", "KEGG_NODE_FILL_COLOR": "#FFFFFF", "name": "container", "SUID": 1012, "selected": false, "KEGG_NODE_TYPE": "group", "KEGG_NODE_WIDTH": "48", "KEGG_NODE_Y": "545", "KEGG_NODE_X": "133", "shared_name": "container", "id": "1012"}}, {"position": {"y": 230.0, "x": 587.0}, "selected": false, "data": {" ...
